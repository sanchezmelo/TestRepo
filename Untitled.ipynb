# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
tesla_data = yf.download("TSLA")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
tesla_data.reset_index(inplace=True)

# %%
print(tesla_data.head())
# Out:
# Price        Date     Close      High       Low      Open     Volume
# Ticker                 TSLA      TSLA      TSLA      TSLA       TSLA
# 0      2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1      2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2      2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3      2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4      2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
pip install requests beautifulsoup4 pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de los ingresos de Tesla (macrotrends)
url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"

# Obtener el contenido de la página
html_data = requests.get(url).text

# Usar BeautifulSoup para analizar la página
soup = BeautifulSoup(html_data, "html.parser")

# Buscar todas las tablas en la página
tables = soup.find_all("table")

# Identificar la tabla correcta (la que contiene los ingresos)
for table in tables:
    if "Tesla Quarterly Revenue" in table.text:
        revenue_table = table
        break

# Extraer los datos de la tabla
tesla_revenue = pd.read_html(str(revenue_table))[0]

# Renombrar columnas si es necesario y limpiar datos
tesla_revenue.columns = ["Date", "Revenue"]
tesla_revenue["Revenue"] = tesla_revenue["Revenue"].str.replace(r"\$", "", regex=True).str.replace(",", "")
tesla_revenue.dropna(inplace=True)
tesla_revenue = tesla_revenue[tesla_revenue["Revenue"] != ""]

# Mostrar las últimas 5 filas
print(tesla_revenue.tail())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 24
#      21         break
#      23 # Extraer los datos de la tabla
# ---> 24 tesla_revenue = pd.read_html(str(revenue_table))[0]
#      26 # Renombrar columnas si es necesario y limpiar datos
#      27 tesla_revenue.columns = ["Date", "Revenue"]
#
# NameError: name 'revenue_table' is not defined

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de la página con los ingresos de Tesla
url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"

# Obtener el contenido HTML de la página
html_data = requests.get(url).text

# Usar BeautifulSoup para parsear el HTML
soup = BeautifulSoup(html_data, "html.parser")

# Encontrar la tabla que contiene "Tesla Quarterly Revenue"
revenue_table = None
tables = soup.find_all("table")

for table in tables:
    if "Tesla Quarterly Revenue" in table.text:
        revenue_table = table
        break

# Verificar si encontró la tabla
if revenue_table is None:
    print("❌ No se encontró la tabla de ingresos.")
else:
    # Leer la tabla usando pandas
    tesla_revenue = pd.read_html(str(revenue_table))[0]

    # Limpiar los datos
    tesla_revenue.columns = ["Date", "Revenue"]
    tesla_revenue["Revenue"] = tesla_revenue["Revenue"].str.replace(r"\$", "", regex=True).str.replace(",", "")
    tesla_revenue.dropna(inplace=True)
    tesla_revenue = tesla_revenue[tesla_revenue["Revenue"] != ""]

    # Mostrar las últimas 5 filas
    print(tesla_revenue.tail())
# Out:
# ❌ No se encontró la tabla de ingresos.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# URL con los ingresos de Tesla
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'

# Obtener el HTML de la página
html_data = requests.get(url).text

# Analizar el HTML
soup = BeautifulSoup(html_data, 'html.parser')

# Buscar la tabla que contiene los ingresos
tablas = soup.find_all("table")
for tabla in tablas:
    if "Tesla Quarterly Revenue" in str(tabla):
        tabla_ingresos = tabla
        break

# Crear el DataFrame
tesla_revenue = pd.read_html(str(tabla_ingresos))[0]

# Limpiar los datos
tesla_revenue.columns = ["Fecha", "Ingresos"]
tesla_revenue["Ingresos"] = tesla_revenue["Ingresos"].str.replace("$", "").str.replace(",", "")
tesla_revenue.dropna(inplace=True)
tesla_revenue = tesla_revenue[tesla_revenue["Ingresos"] != ""]

# Convertir a tipo numérico
tesla_revenue["Ingresos"] = pd.to_numeric(tesla_revenue["Ingresos"])

# Mostrar las últimas 5 filas
print(tesla_revenue.tail())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 22
#      19         break
#      21 # Crear el DataFrame
# ---> 22 tesla_revenue = pd.read_html(str(tabla_ingresos))[0]
#      24 # Limpiar los datos
#      25 tesla_revenue.columns = ["Fecha", "Ingresos"]
#
# NameError: name 'tabla_ingresos' is not defined

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'

# %%
pip install pandas beautifulsoup4 lxml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 144.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# URL de los ingresos de Tesla en Macrotrends
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'

# Descargar el HTML
html_data = requests.get(url).text

# Analizar con BeautifulSoup
soup = BeautifulSoup(html_data, 'html.parser')

# Buscar todas las tablas
tablas = soup.find_all("table")

# Variable para almacenar la tabla de ingresos
tabla_ingresos = None

# Buscar la tabla correcta
for tabla in tablas:
    if "Tesla Quarterly Revenue" in tabla.text:
        tabla_ingresos = tabla
        break

# Verificar si se encontró la tabla
if tabla_ingresos is not None:
    # Convertir HTML a DataFrame
    tesla_revenue = pd.read_html(str(tabla_ingresos))[0]

    # Renombrar columnas
    tesla_revenue.columns = ["Fecha", "Ingresos"]

    # Limpiar datos
    tesla_revenue["Ingresos"] = tesla_revenue["Ingresos"].str.replace("$", "", regex=False).str.replace(",", "", regex=False)
    tesla_revenue = tesla_revenue[tesla_revenue["Ingresos"] != ""]
    tesla_revenue.dropna(inplace=True)

    # Convertir ingresos a numérico
    tesla_revenue["Ingresos"] = pd.to_numeric(tesla_revenue["Ingresos"])

    # Mostrar las últimas 5 filas
    print(tesla_revenue.tail())
else:
    print("❌ No se encontró la tabla de ingresos de Tesla.")
# Out:
# ❌ No se encontró la tabla de ingresos de Tesla.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# URL de los ingresos de Tesla en Macrotrends
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'

# Obtener el HTML de la página
html_data = requests.get(url).text

# Analizar el HTML
soup = BeautifulSoup(html_data, 'html.parser')

# Buscar la tabla que contiene los ingresos trimestrales
tabla = soup.find_all("table")[1]  # La segunda tabla contiene los datos trimestrales

# Leer la tabla con pandas
tesla_revenue = pd.read_html(str(tabla))[0]

# Renombrar columnas
tesla_revenue.columns = ["Fecha", "Ingresos"]

# Limpiar los datos
tesla_revenue["Ingresos"] = tesla_revenue["Ingresos"].str.replace("$", "").str.replace(",", "")
tesla_revenue = tesla_revenue[tesla_revenue["Ingresos"] != ""]
tesla_revenue.dropna(inplace=True)

# Convertir ingresos a tipo numérico
tesla_revenue["Ingresos"] = pd.to_numeric(tesla_revenue["Ingresos"])

# Mostrar las últimas 5 filas
print(tesla_revenue.tail())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 15
#      12 soup = BeautifulSoup(html_data, 'html.parser')
#      14 # Buscar la tabla que contiene los ingresos trimestrales
# ---> 15 tabla = soup.find_all("table")[1]  # La segunda tabla contiene los datos trimestrales
#      17 # Leer la tabla con pandas
#      18 tesla_revenue = pd.read_html(str(tabla))[0]
#
# IndexError: list index out of range

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# URL de los ingresos de Tesla en Macrotrends
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'

# Obtener el HTML de la página
html_data = requests.get(url).text

# Analizar el HTML
soup = BeautifulSoup(html_data, 'html.parser')

# Buscar la tabla que contiene los ingresos trimestrales
tabla = soup.find_all("table")[1]  # La segunda tabla contiene los datos trimestrales

# Leer la tabla con pandas
tesla_revenue = pd.read_html(str(tabla))[0]

# Renombrar columnas
tesla_revenue.columns = ["Fecha", "Ingresos"]

# Limpiar los datos
tesla_revenue["Ingresos"] = tesla_revenue["Ingresos"].str.replace("$", "").str.replace(",", "")
tesla_revenue = tesla_revenue[tesla_revenue["Ingresos"] != ""]
tesla_revenue.dropna(inplace=True)

# Convertir ingresos a tipo numérico
tesla_revenue["Ingresos"] = pd.to_numeric(tesla_revenue["Ingresos"])

# Mostrar las últimas 5 filas
print(tesla_revenue.tail())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 15
#      12 soup = BeautifulSoup(html_data, 'html.parser')
#      14 # Buscar la tabla que contiene los ingresos trimestrales
# ---> 15 tabla = soup.find_all("table")[1]  # La segunda tabla contiene los datos trimestrales
#      17 # Leer la tabla con pandas
#      18 tesla_revenue = pd.read_html(str(tabla))[0]
#
# IndexError: list index out of range

# %%
# !pip install pandas
# !pip install requests
# !pip install bs4
# !pip install html5lib 
# !pip install lxml
# !pip install plotly

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/netflix_data_webpage.html"

# %%
data  = requests.get(url).text
print(data)
# Out:
# <!DOCTYPE html><html id="atomic" class="NoJs chrome desktop" lang="en-US"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark('PageStart');</script><meta charset="utf-8"/><title>Netflix, Inc. (NFLX) Stock Historical Prices &amp; Data - Yahoo Finance</title><meta name="keywords" content="NFLX, Netflix, Inc., NFLX historical prices, Netflix, Inc. historical prices, historical prices, stocks, quotes, finance"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta property="twitter:dnt" content="on"/><meta property="fb:app_id" content="458584288257241"/><meta name="theme-color" content="#400090"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="description" lang="en-US" content="Discover historical prices for NFLX stock on Yahoo Finance. View daily, weekly or monthly format back to when Netflix, Inc. stock was issued."/><meta name="oath:guce:consent-host" content="guce.yahoo.com"/><m
# ...

# %%
soup = BeautifulSoup(data, 'html.parser')

# %%
netflix_data = pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Volume"])

# %%
# First we isolate the body of the table which contains all the information
# Then we loop through each row and find all the column values for each row
for row in soup.find("tbody").find_all('tr'):
    col = row.find_all("td")
    date = col[0].text
    Open = col[1].text
    high = col[2].text
    low = col[3].text
    close = col[4].text
    adj_close = col[5].text
    volume = col[6].text
    
    # Finally we append the data of each row to the table
    netflix_data = pd.concat([netflix_data,pd.DataFrame({"Date":[date], "Open":[Open], "High":[high], "Low":[low], "Close":[close], "Adj Close":[adj_close], "Volume":[volume]})], ignore_index=True)

# %%
netflix_data.head()
# Out:
#            Date    Open    High     Low   Close       Volume Adj Close
# 0  Jun 01, 2021  504.01  536.13  482.14  528.21   78,560,600    528.21
# 1  May 01, 2021  512.65  518.95  478.54  502.81   66,927,600    502.81
# 2  Apr 01, 2021  529.93  563.56  499.00  513.47  111,573,300    513.47
# 3  Mar 01, 2021  545.57  556.99  492.85  521.66   90,183,900    521.66
# 4  Feb 01, 2021  536.79  566.65  518.28  538.85   61,902,300    538.85

# %%
read_html_pandas_data = pd.read_html(url)

# %%
read_html_pandas_data = pd.read_html(str(soup))

# %%
netflix_dataframe = read_html_pandas_data[0]

netflix_dataframe.head()
# Out:
#            Date    Open    High     Low  Close* Adj Close**     Volume
# 0  Jun 01, 2021  504.01  536.13  482.14  528.21      528.21   78560600
# 1  May 01, 2021  512.65  518.95  478.54  502.81      502.81   66927600
# 2  Apr 01, 2021  529.93  563.56  499.00  513.47      513.47  111573300
# 3  Mar 01, 2021  545.57  556.99  492.85  521.66      521.66   90183900
# 4  Feb 01, 2021  536.79  566.65  518.28  538.85      538.85   61902300

# %%
amazon_data = pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Volume"])

for row in soup.find("tbody").find_all("tr"):
    col = row.find_all("td")
    date = #ADD_CODE
    Open = #ADD_CODE
    high = #ADD_CODE
    low = #ADD_CODE
    close = #ADD_CODE
    adj_close = #ADD_CODE
    volume = #ADD_CODE
    
    amazon_data = pd.concat([amazon_data, pd.DataFrame({"Date":[date], "Open":[Open], "High":[high], "Low":[low], "Close":[close], "Adj Close":[adj_close], "Volume":[volume]})], ignore_index=True)
# Out:
#   Cell In[16], line 5
#     date = #ADD_CODE
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# URL de los ingresos de Tesla en Macrotrends
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'

# Obtener el HTML de la página
html_data = requests.get(url).text

# Analizar el HTML
soup = BeautifulSoup(html_data, 'html.parser')

# Buscar la tabla que contiene los ingresos trimestrales
tabla = soup.find_all("table")[1]  # La segunda tabla contiene los datos trimestrales

# Leer la tabla con pandas
tesla_revenue = pd.read_html(str(tabla))[0]

# Renombrar columnas
tesla_revenue.columns = ["Fecha", "Ingresos"]

# Limpiar los datos
tesla_revenue["Ingresos"] = tesla_revenue["Ingresos"].str.replace("$", "").str.replace(",", "")
tesla_revenue = tesla_revenue[tesla_revenue["Ingresos"] != ""]
tesla_revenue.dropna(inplace=True)

# Convertir ingresos a tipo numérico
tesla_revenue["Ingresos"] = pd.to_numeric(tesla_revenue["Ingresos"])

# Mostrar las últimas 5 filas
print(tesla_revenue.tail())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 15
#      12 soup = BeautifulSoup(html_data, 'html.parser')
#      14 # Buscar la tabla que contiene los ingresos trimestrales
# ---> 15 tabla = soup.find_all("table")[1]  # La segunda tabla contiene los datos trimestrales
#      17 # Leer la tabla con pandas
#      18 tesla_revenue = pd.read_html(str(tabla))[0]
#
# IndexError: list index out of range

# %%
# Pregunta 1: Instalar y cargar librerías necesarias
import pandas as pd
import yfinance as yf
import requests
from bs4 import BeautifulSoup

# Pregunta 2: Webscraping - Obtener ingresos de Tesla
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, 'html.parser')

# Buscar todas las tablas
tablas = soup.find_all("table")

# Buscar la tabla de ingresos
tabla_ingresos = None
for tabla in tablas:
    if "Tesla Quarterly Revenue" in tabla.text:
        tabla_ingresos = tabla
        break

# Crear DataFrame si se encontró la tabla
if tabla_ingresos is not None:
    tesla_revenue = pd.read_html(str(tabla_ingresos))[0]
    tesla_revenue.columns = ["Fecha", "Ingresos"]
    tesla_revenue["Ingresos"] = tesla_revenue["Ingresos"].str.replace("$", "").str.replace(",", "")
    tesla_revenue = tesla_revenue[tesla_revenue["Ingresos"] != ""]
    tesla_revenue.dropna(inplace=True)
    tesla_revenue["Ingresos"] = pd.to_numeric(tesla_revenue["Ingresos"])
    print("Últimas 5 filas de tesla_revenue:")
    print(tesla_revenue.tail())
else:
    print("❌ No se encontró la tabla de ingresos de Tesla.")

# Pregunta 3: Usar yfinance para obtener datos de GME
gme_data = yf.download("GME", start="2010-01-01", end="2024-12-31")

# Reiniciar el índice
gme_data.reset_index(inplace=True)

# Mostrar las primeras 5 filas
print("\nPrimeras 5 filas de gme_data:")
print(gme_data.head())

# Guardar el DataFrame como CSV si lo deseas
#gme_data.to_csv("gme_data.csv", index=False)
# Out:
# ❌ No se encontró la tabla de ingresos de Tesla.
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Primeras 5 filas de gme_data:
# Price        Date     Close      High       Low      Open     Volume
# Ticker                  GME       GME       GME       GME        GME
# 0      2010-01-04  3.854643  3.863059  3.703150  3.714933   26702800
# 1      2010-01-05  3.959004  3.996035  3.854642  3.856326   21269600
# 2      2010-01-06  4.044851  4.056634  3.908508  3.948906   21471200
# 3      2010-01-07  3.443930  3.563441  3.268872  3.368184  164761200
# 4      2010-01-08  3.415314  3.573539  3.405214  3.474228   47872400

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# URL de los ingresos de GameStop en Macrotrends
url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'

# Obtener el contenido HTML de la página
html_data = requests.get(url).text

# Analizar el HTML con BeautifulSoup
soup = BeautifulSoup(html_data, 'html.parser')

# Buscar todas las tablas en la página
tablas = soup.find_all("table")

# Inicializar la variable para la tabla de ingresos
tabla_ingresos = None

# Buscar la tabla que contiene "GameStop Quarterly Revenue"
for tabla in tablas:
    if "GameStop Quarterly Revenue" in tabla.text:
        tabla_ingresos = tabla
        break

# Verificar si se encontró la tabla
if tabla_ingresos is not None:
    # Leer la tabla HTML con pandas
    gme_revenue = pd.read_html(str(tabla_ingresos))[0]
    
    # Renombrar las columnas
    gme_revenue.columns = ["Fecha", "Ingresos"]
    
    # Eliminar filas con valores vacíos en "Ingresos"
    gme_revenue = gme_revenue[gme_revenue["Ingresos"] != ""]
    
    # Eliminar el símbolo de dólar y las comas, y convertir a numérico
    gme_revenue["Ingresos"] = gme_revenue["Ingresos"].str.replace("$", "", regex=False).str.replace(",", "", regex=False)
    gme_revenue["Ingresos"] = pd.to_numeric(gme_revenue["Ingresos"])
    
    # Mostrar las últimas cinco filas del DataFrame
    print(gme_revenue.tail())
else:
    print("❌ No se encontró la tabla de ingresos trimestrales de GameStop.")
# Out:
# ❌ No se encontró la tabla de ingresos trimestrales de GameStop.

# %%
pip install pandas requests beautifulsoup4 lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# URL de los ingresos de GameStop en Macrotrends
url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'

# Obtener el contenido HTML de la página
html_data = requests.get(url).text

# Analizar el HTML con BeautifulSoup
soup = BeautifulSoup(html_data, 'html.parser')

# Buscar todas las tablas en la página
tablas = soup.find_all("table")

# Inicializar la variable para la tabla de ingresos
tabla_ingresos = None

# %%
# Buscar la tabla que contiene "GameStop Quarterly Revenue"
for tabla in tablas:
    if "GameStop Quarterly Revenue" in tabla.text:
        tabla_ingresos = tabla
        break

# %%
 gme_revenue = pd.read_html(str(tabla_ingresos))[0]
# Out:
# /tmp/ipykernel_1817/3095844273.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   gme_revenue = pd.read_html(str(tabla_ingresos))[0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 gme_revenue = pd.read_html(str(tabla_ingresos))[0]
#
# File /opt/conda/lib/python3.12/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
# ...

# %%
import pandas as pd

# URL de los ingresos de GameStop en Macrotrends
url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'

# Leer la tabla que contiene "GameStop Quarterly Revenue"
try:
    gme_revenue = pd.read_html(url, match="GameStop Quarterly Revenue")[0]
    
    # Renombrar las columnas
    gme_revenue.columns = ["Fecha", "Ingresos"]
    
    # Limpiar los datos
    gme_revenue["Ingresos"] = gme_revenue["Ingresos"].replace('[\$,]', '', regex=True)
    gme_revenue["Ingresos"] = pd.to_numeric(gme_revenue["Ingresos"])
    
    # Mostrar las últimas cinco filas
    print(gme_revenue.tail())
except ValueError:
    print("❌ No se encontró la tabla de ingresos trimestrales de GameStop en la página proporcionada.")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       6 # Leer la tabla que contiene "GameStop Quarterly Revenue"
#       7 try:
# ----> 8     gme_revenue = pd.read_html(url, match="GameStop Quarterly Revenue")[0]
#      10     # Renombrar las columnas
#      11     gme_revenue.columns = ["Fecha", "Ingresos"]
#
# File /opt/conda/lib/python3.12/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
# ...

# %%
import yfinance as yf
import pandas

gme_data = yf.Ticker("GME")


financials = gme_data.quarterly_financials.T  


if 'Total Revenue' in financials.columns:
    gme_revenue = financials[['Total Revenue']]
    print(gme_revenue.tail())
else:
    print("No se encontró la columna 'Total Revenue' en los datos financieros trimestrales.")
# Out:
#            Total Revenue
# 2024-10-31   860300000.0
# 2024-07-31   798300000.0
# 2024-04-30           NaN
# 2024-01-31  1793600000.0
# 2023-10-31  1078300000.0

# %%
import yfinance as yf
import matplotlib.pyplot as plt


tesla_data = yf.download('TSLA', start='2010-01-01', end='2024-12-31')


def make_graph(stock_data, title):
    plt.figure(figsize=(14, 7))
    plt.plot(stock_data.index, stock_data['Close'], label='Precio de cierre', color='blue')
    plt.title(title)
    plt.xlabel('Fecha')
    plt.ylabel('Precio (USD)')
    plt.grid(True)
    plt.legend()
    plt.show()


make_graph(tesla_data, 'Precio de las acciones de Tesla (TSLA)')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 import yfinance as yf
# ----> 2 import matplotlib.pyplot as plt
#       5 tesla_data = yf.download('TSLA', start='2010-01-01', end='2024-12-31')
#       8 def make_graph(stock_data, title):
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 125.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 104.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 74.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 134.0 MB/s eta 0:00:00
# ...

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Descargar datos de Tesla
tesla_data = yf.download('TSLA', start='2010-01-01', end='2024-12-31')

# Función para graficar
def make_graph(stock_data, title):
    plt.figure(figsize=(14, 7))
    plt.plot(stock_data.index, stock_data['Close'], label='Precio de cierre', color='blue')
    plt.title(title)
    plt.xlabel('Fecha')
    plt.ylabel('Precio (USD)')
    plt.grid(True)
    plt.legend()
    plt.show()

# Llamada a la función
make_graph(tesla_data, 'Precio de las acciones de Tesla (TSLA)')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Descargar datos históricos de GameStop
gme_data = yf.download('GME', start='2010-01-01', end='2024-12-31')

# Función para graficar
def make_graph(stock_data, title):
    plt.figure(figsize=(14, 7))
    plt.plot(stock_data.index, stock_data['Close'], label='Precio de cierre', color='darkred')
    plt.title(title)
    plt.xlabel('Fecha')
    plt.ylabel('Precio (USD)')
    plt.grid(True)
    plt.legend()
    plt.show()

# Graficar los datos de GME
make_graph(gme_data, 'Precio de las acciones de GameStop (GME)')
# Out:
# [*********************100%***********************]  1 of 1 completed
